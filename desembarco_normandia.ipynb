# %% [markdown]
# # I. Exploración y preparación del dato
#
# * Carga del dataset
# * Dimensiones
# * Tipos de columnas
# * Volumen de registros

# %%
import pandas as pd

# %% [markdown]
# ## DATASET: 1_CLEANBOMBWW2.CSV
#
# >

# %%
# 1. Cargar el dataset (Asegúrate de poner la ruta correcta de tu archivo)
# Si estás en Colab, recuerda subir el archivo antes a la carpeta de la izquierda
df_1_clean_bomb = pd.read_csv('data/1_cleanbombww2.csv', low_memory=False) # low_memory=False para evitar advertencias de tipos de datos mixtos

# 2. Inspección rápida: ¿Qué forma tiene y cómo se llaman las columnas?
print("--- DIMENSIONES DEL DATASET ---")
print(f"Filas: {df_1_clean_bomb.shape[0]} | Columnas: {df_1_clean_bomb.shape[1]}\n")

print("--- LISTADO DE COLUMNAS DISPONIBLES ---")
df_1_clean_bomb.columns.tolist() # así salen como una lista de Python, más fácil de leer
# Out:
# --- DIMENSIONES DEL DATASET ---
# Filas: 1109 | Columnas: 21
#
# --- LISTADO DE COLUMNAS DISPONIBLES ---
# ['Unnamed: 0',
#  'Mission ID',
#  'Mission Date',
#  'Theater of Operations',
#  'Country',
#  'Air Force',
#  'Unit ID',
#  'Aircraft Series',
#  'Takeoff Base',
#  'Takeoff Location',
#  'Takeoff Latitude',
#  'Takeoff Longitude',
#  'Target Country',
#  'Target City',
#  'Target Latitude',
#  'Target Longitude',
#  'Airborne Aircraft',
#  'Bombing Aircraft',
#  'High Explosives Type',
#  'High Explosives Weight (Tons)',
#  'Total Weight (Tons)']
